# %% [raw]
# Before we can do anything with pandas, we need to import its library into our Jupyter Notebook.

# %%
import pandas as pd
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)

# %% [raw]
# Ok! Let's go ahead and load our raw data file into a DataFrame we'll call "df_census". It's a big file, so we'll use .head() to inspect the first few rows and get a sense of the data.

# %%
file_census = "git/data/DECENNIALPL2020.P1_data_with_overlays_2021-12-02T121459.csv"
df_census = pd.read_csv(file_census, low_memory=False)
df_census.head()
# Out:
#                  GEO_ID                                       NAME    P1_001N  \
# 0                    id                       Geographic Area Name   !!Total:
# 1  1400000US01001020100  Census Tract 201, Autauga County, Alabama       1775
# 2  1400000US01001020200  Census Tract 202, Autauga County, Alabama       2055
# 3  1400000US01001020300  Census Tract 203, Autauga County, Alabama       3216
# 4  1400000US01001020400  Census Tract 204, Autauga County, Alabama       4246
#
#                               P1_002N  \
# 0   !!Total:!!Population of one race:
# 1                                1653
# 2                                1984
# 3                                3039
# 4                                3993
#
#                                            P1_003N  \
# 0   !!Total:!!Population of one race:!!White alone
# 1                                             1389
# 2                                              842
# 3                                             2244
# ...

# %% [raw]
# To get a better overall sense of what we're working with, let's use .info() to get some basic stats about our data.

# %%
df_census.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 85396 entries, 0 to 85395
# Data columns (total 73 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   GEO_ID   85396 non-null  object
#  1   NAME     85396 non-null  object
#  2   P1_001N  85396 non-null  object
#  3   P1_002N  85396 non-null  object
#  4   P1_003N  85396 non-null  object
#  5   P1_004N  85396 non-null  object
#  6   P1_005N  85396 non-null  object
#  7   P1_006N  85396 non-null  object
#  8   P1_007N  85396 non-null  object
#  9   P1_008N  85396 non-null  object
#  10  P1_009N  85396 non-null  object
#  11  P1_010N  85396 non-null  object
#  12  P1_011N  85396 non-null  object
#  13  P1_012N  85396 non-null  object
#  14  P1_013N  85396 non-null  object
#  15  P1_014N  85396 non-null  object
#  16  P1_015N  85396 non-null  object
#  17  P1_016N  85396 non-null  object
#  18  P1_017N  85396 non-null  object
#  19  P1_018N  85396 non-null  object
# ...

# %% [raw]
# From the above we've learned the following about our DataFrame.
#
# - it has 85,396 entries (rows) and 73 columns
# - there are no null values in any of the columns, at least at first glance. (We'll double check this separately.)
# - even though we know from looking at the first few rows earlier that data in almost every column is numerical, all of the columns are actually of datatype object. This means they are probably formatted as strings.

# %% [raw]
# We've seen that our columns have cryptic names that begin with "P1_". We're going to use the seperate metadata file that came with our raw census data to fix this. Let's load the metadata file that came with our data file into a DataFrame we'll call "df_meta_data'. Then we can cleanup any weird characters.
#
# (We're really only interested in column P1_001N, total population, but we're going to fix all of the column names because it's just as easy as taking care of one.)

# %%
file_metadata = "git/data/DECENNIALPL2020.P1_metadata_2021-12-02T121459.csv"
df_metadata = pd.read_csv(file_metadata, low_memory=False)
df_metadata
# Out:
#      GEO_ID  \
# 0      NAME
# 1   P1_001N
# 2   P1_002N
# 3   P1_003N
# 4   P1_004N
# 5   P1_005N
# 6   P1_006N
# 7   P1_007N
# 8   P1_008N
# 9   P1_009N
# 10  P1_010N
# 11  P1_011N
# 12  P1_012N
# 13  P1_013N
# 14  P1_014N
# 15  P1_015N
# 16  P1_016N
# 17  P1_017N
# 18  P1_018N
# 19  P1_019N
# 20  P1_020N
# 21  P1_021N
# 22  P1_022N
# 23  P1_023N
# 24  P1_024N
# 25  P1_025N
# 26  P1_026N
# 27  P1_027N
# 28  P1_028N
# 29  P1_029N
# 30  P1_030N
# 31  P1_031N
# 32  P1_032N
# 33  P1_033N
# 34  P1_034N
# 35  P1_035N
# 36  P1_036N
# 37  P1_037N
# 38  P1_038N
# 39  P1_039N
# 40  P1_040N
# 41  P1_041N
# 42  P1_042N
# 43  P1_043N
# 44  P1_044N
# 45  P1_045N
# 46  P1_046N
# 47  P1_047N
# 48  P1_048N
# 49  P1_049N
# 50  P1_050N
# 51  P1_051N
# 52  P1_052N
# 53  P1_053N
# 54  P1_054N
# 55  P1_055N
# 56  P1_056N
# 57  P1_057N
# 58  P1_058N
# 59  P1_059N
# 60  P1_060N
# 61  P1_061N
# 62  P1_062N
# 63  P1_063N
# 64  P1_064N
# 65  P1_065N
# 66  P1_066N
# 67  P1_067N
# 68  P1_068N
# 69  P1_069N
# ...

# %%
df_metadata_id.replace('!!', ' ')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_20296/160992104.py in <module>
# ----> 1 df_metadata_id.replace('!!', ' ')
#
# NameError: name 'df_metadata_id' is not defined

# %%
df_metadata
